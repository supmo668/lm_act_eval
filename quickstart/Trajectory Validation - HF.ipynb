# %%
from pathlib import Path
import os
from dotenv import load_dotenv

# %load_ext autoreload
# %autoreload 2

# %%
# change dir to ml repo at ml/ root (if you started in notebook/)
os.chdir('../')
print(Path.cwd())
load_dotenv()
# Out:
# /home/opadmin/llama2d_opentable/lm_act_eval
# True

# %%
# read dataset into datasets
from datasets import Dataset
import pandas as pd
dataset_name = "five-star-trajectories"
dataset_path = Path(f"lm_act_eval/.cache/{dataset_name }")
traj_df = pd.read_csv(dataset_path/"csv/data.csv")
traj_dataset = Dataset.from_pandas(traj_df)
print(traj_df.columns)
traj_df[traj_df.session_id==traj_df.session_id.unique()[0]]
traj_df.head(2)
# Out:
# Index(['session_id', 'idx_in_session', '_id', 'event_id', 'parent_id',
#        'event_type', 'event_name', 'config', 'children_ids', 'inputs',
#        'outputs', 'error', 'start_time', 'end_time', 'metadata', 'feedback',
#        'metrics', 'user_properties', 'source', 'duration', 'project_id',
#        'tenant', 'QUERY', 'URL', 'DOM', 'RULES', 'USER_CONTEXT',
#        'PREV_ACTIONS', 'chat_history', 'CURRENT_TIME', 'planPrompt',
#        'previousActionsRepetitionPrompt', 'chat_completion_messages',
#        'ground_truth', 'screenshot', 'prompt', 'internal_metadata'],
#       dtype='object')
#                              session_id idx_in_session  \
# 0  ce3bf1c8-371a-4adb-98e6-2cce19c1aff5              0
# 1  ce3bf1c8-371a-4adb-98e6-2cce19c1aff5              1
#
#                         _id                              event_id  \
# 0  65f0c5d705cef8bdb70153a9  cc3d0d22-4759-43d8-a688-d174ca94f9dd
# 1  65f0c60705cef8bdb70153ab  44b78fc2-24e2-40e5-b39d-e887a7129587
#
#                               parent_id event_type        event_name  \
# 0  ce3bf1c8-371a-4adb-98e6-2cce19c1aff5      model  Model Completion
# 1  ce3bf1c8-371a-4adb-98e6-2cce19c1aff5      model  Model Completion
#
#                                               config children_ids  \
# 0  {'model': 'gpt-4-1106-preview', 'provider': 'u...           []
# 1  {'model': 'gpt-4-1106-preview', 'provider': 'u...           []
#
#                                               inputs  ...  \
# 0  {'QUERY': 'Find a restaurant with vegetarian o...  ...
# 1  {'QUERY': 'Find a restaurant with vegetarian o...  ...
#
#                                         PREV_ACTIONS  \
# 0                                                NaN
# 1  - I am searching for restaurants with vegetari...
#
#                                         chat_history  \
# 0                                                 []
# 1  [{'role': 'user', 'content': 'Find a restauran...
#
#                                 CURRENT_TIME  \
# 0  Tuesday, March 12, 2024 at 4:14:11 PM CDT
# 1  Tuesday, March 12, 2024 at 4:15:02 PM CDT
#
#                                           planPrompt  \
# 0  IMPORTANT: If the objective is complex, compri...
# 1  IMPORTANT: If the objective is complex, compri...
#
#                      previousActionsRepetitionPrompt  \
# 0  **PREVIOUS ACTIONS Repetition**:\n- Review the...
# 1  **PREVIOUS ACTIONS Repetition**:\n- Review the...
#
#                             chat_completion_messages  \
# 0  [{'role': 'system', 'content': '**Goal**: Let\...
# 1  [{'role': 'system', 'content': '**Goal**: Let\...
#
#                                         ground_truth  \
# 0  PLAN: To find a restaurant with vegetarian opt...
# 1  The search for "vegetarian" in St. Louis has y...
#
#                                           screenshot prompt  internal_metadata
# 0  https://multion-client-screenshots.s3.us-east-...    NaN                NaN
# 1  https://multion-client-screenshots.s3.us-east-...    NaN                NaN
#
# [2 rows x 37 columns]

# %%
from lm_act_eval.evaluation_harness.helper_functions.multion import (
  action_prefix,
  clean_extracted_text,
  extract_thought,
  extract_action,
  extract_explanation,
  ParseChatCompletion
)
from lm_act_eval.evaluation_harness.utils.url import is_screenshot_url_accessible
from typing import Callable
from tqdm import tqdm
tqdm.pandas()
# Out:
# Google Cloud not set up, skipping import of providers.gemini_utils.generate_from_gemini_completion
# Google Cloud not set up, skipping import of vertexai.preview.generative_models.Image and llms.generate_from_gemini_completion

# %% [markdown]
# ### Load other data

# %%
traj_df = pd.read_csv(dataset_path/'csv/data+gptv.csv')

# %% [markdown]
# ### completions

# %%
from lm_act_eval.evaluation_harness.constants import BNB_QUANTIZATION_CONFIG_8BIT, BitsAndBytesConfig

from lm_act_eval.common.hf import load_model_and_tokenizer
from lm_act_eval.evaluation_harness.evaluators.sft.utils import generate_text_and_merge

# %%
from concurrent.futures import ProcessPoolExecutor
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer
import torch

# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_name = "MULTION-AI/feasible-morning-17-v4"
# Load the tokenizer and model
bnb = True
tokenizer = AutoTokenizer.from_pretrained(model_name)
if not bnb:
  model = AutoModelForCausalLM.from_pretrained(model_name)
else:
  quantization_config = BitsAndBytesConfig(load_in_8bit_fp32_cpu_offload=True)
  model = AutoModelForCausalLM.from_pretrained(
    model_name, low_cpu_mem_usage=True, 
    device_map="auto", quantization_config=quantization_config, 
    max_memory={**{k:'8000Mib' for k in range(0,8)}, "cpu": '100Gib'}
  )
# Out:
# Loading checkpoint shards: 100%|██████████| 19/19 [00:46<00:00,  2.46s/it]

# %%
import wandb
# Initialize Wandb
wandb.login()
wandb.init(
  project="trajectory_eval", entity="multion-agi",
  name=f"opentable-{model_name}", reinit=True)

# %%
traj_df_generated = generate_text_and_merge(
    traj_df,
    "chat_completion_messages_content",
    model,
    tokenizer,
    model.device,
    max_new_tokens=256,
    batch_size=2
)
# Out:
# Generate from chat_completion_messages_content:   0%|          | 0/1691 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:   0%|          | 1/1691 [00:53<25:01:40, 53.31s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:   0%|          | 2/1691 [01:29<20:14:31, 43.14s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:   0%|          | 3/1691 [02:07<19:05:32, 40.72s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:   0%|          | 4/1691 [02:41<17:58:27, 38.36s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:   0%|          | 5/1691 [03:18<17:40:25, 37.74s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:   0%|          | 6/1691 [04:04<18:57:53, 40.52s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:   0%|          | 7/1691 [04:39<18:09:11, 38.81s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:   0%|          | 8/1691 [05:12<17:18:34, 37.03s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:   1%|          | 9/1691 [05:58<18:31:52, 39.66s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:   1%|          | 10/1691 [06:38<18:32:13, 39.70s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:   1%|          | 11/1691 [07:22<19:09:15, 41.04s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:
/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  18%|█▊        | 302/1691 [3:16:23<15:59:08, 41.43s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  18%|█▊        | 303/1691 [3:17:08<16:27:25, 42.68s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  18%|█▊        | 304/1691 [3:17:53<16:39:00, 43.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  18%|█▊        | 305/1691 [3:18:39<17:02:29, 44.26s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  18%|█▊        | 306/1691 [3:18:53<13:31:13, 35.14s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  18%|█▊        | 307/1691 [3:19:40<14:53:08, 38.72s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  18%|█▊        | 308/1691 [3:20:29<15:57:52, 41.56s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  18%|█▊        | 309/1691 [3:21:07<15:33:43, 40.54s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  18%|█▊        | 310/1691 [3:21:44<15:12:46, 39.66s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  18%|█▊        | 311/1691 [3:22:24<15:15:15, 39.79s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  18%|█▊        | 312/1691 [3:23:06<15:28:17, 40.39s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▊        | 313/1691 [3:23:49<15:45:43, 41.18s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▊        | 314/1691 [3:24:29<15:38:34, 40.90s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▊        | 315/1691 [3:25:04<14:56:35, 39.10s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▊        | 316/1691 [3:25:45<15:04:33, 39.47s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▊        | 317/1691 [3:26:19<14:29:44, 37.98s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▉        | 318/1691 [3:27:02<14:59:27, 39.31s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▉        | 319/1691 [3:27:36<14:21:42, 37.68s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▉        | 320/1691 [3:28:09<13:53:19, 36.47s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▉        | 321/1691 [3:28:50<14:19:44, 37.65s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▉        | 322/1691 [3:29:24<13:57:12, 36.69s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▉        | 323/1691 [3:30:07<14:40:11, 38.60s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▉        | 324/1691 [3:30:49<15:02:31, 39.61s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▉        | 325/1691 [3:31:28<14:58:19, 39.46s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▉        | 326/1691 [3:32:09<15:06:33, 39.85s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▉        | 327/1691 [3:32:19<11:41:25, 30.85s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▉        | 328/1691 [3:33:01<12:57:44, 34.24s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  19%|█▉        | 329/1691 [3:33:43<13:51:57, 36.65s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generate from chat_completion_messages_content:  20%|█▉        | 330/1691 [3:34:26<14:32:43, 38.47s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.

# %%
# def generate_respsonse(
#     row, pipeline, inp_column="completion_msg_content", log=False, max_new_tokens=256):
#     response = pipeline(
#         row[inp_column], max_new_tokens=max_new_tokens, num_return_sequences=1)
#     generated_text = response[0]["generated_text"]
#     if log:
#         wandb.log({
#             "original_text": row[inp_column],
#             "generated_text": generated_text})
#     return generated_text

# # responses = []
# # for index, row in tqdm(traj_df.iterrows(), desc="generating completions"):
# #     responses.append(generate_respsonse(
# #         row, inp_column="completion_msg_content", log=False
# #     ))
# # traj_df['generated_responses'] = responses

# %%
# Apply the function to each row in the DataFrame
tqdm.pandas()
traj_df['generated_responses\''] = traj_df[['completion_msg_content']].progress_apply(
  lambda x: generate_respsonse(x, log=False), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 3
#       1 # Apply the function to each row in the DataFrame
#       2 tqdm.pandas()
# ----> 3 traj_df['generated_responses\''] = traj_df[['completion_msg_content']].progress_apply(
#       4   lambda x: generate_respsonse(x, log=False), axis=1)
#
# File ~/anaconda3/envs/eval/lib/python3.11/site-packages/pandas/core/frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/eval/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/eval/lib/python3.11/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['completion_msg_content'], dtype='object')] are in the [columns]"

# %%
traj_df_new_gen = traj_df.copy()
traj_df_new_gen.to_csv(dataset_path/f'csv/data+gen_{model_name}.csv', index=False)

# %% [markdown]
# Logging

# %%
# log data
import wandb
from dotenv import load_dotenv
load_dotenv()
wandb.login(relogin=True)

# %%
opentable_artifact = wandb.Artifact("opentable_trajectories_gptv.v0", type="dataset")
# opentable_table = wandb.Table(dataframe=traj_df_new)
opentable_table_eligible = wandb.Table(dataframe=traj_df)
#
# opentable_artifact.add(opentable_table, "opentable")
opentable_artifact.add(opentable_table_eligible, "opentable-eligibleonly")
# opentable_artifact.add_file(str(dataset_path/'csv/data+gptv.csv'))
opentable_artifact.add_file(str(dataset_path/'csv/data+gptv-eligible.csv'))

# %%
# Start a W&B run to log data
run = wandb.init(project="opentable-vision", reinit=True)
# Log the table to visualize with a run...
run.log({"opentable_gptv": opentable_table_eligible})

# and Log as an Artifact to increase the available row limit!
run.log_artifact(opentable_artifact)

# %% [markdown]
# ### Process data

# %%
traj_df

# %% [markdown]
# ### Eval Metrics

# %%
from autoevals.llm import *
from autoevals.string import Levenshtein
import warnings
levenshtein_evaluator = Levenshtein()
# Out:
# 0.8

# %%
config_metrics = {
    "Actions": {"edit": "edit"}
}
metric_registry = {
    "edit": Levenshtein()
}
def evaluate_trajectory(dataset):
    """
    eligible dataset
    """
    metric_results = []
    for index, row in dataset[eligible].iterrows():
        result_row = {}
        for metric_config in config_metrics:
            metric_name = metric_config["name"]
            if metric_registry.get(metric_name):
                metric_func = metric_registry[metric_name]
                result_row[metric_name] = metric_func(row)
        metric_results.append(result_row)

# %% [markdown]
# ### Logging

# %%
# log data
import wandb
from dotenv import load_dotenv
load_dotenv()
wandb.login(relogin=True)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Appending key for api.wandb.ai to your netrc file: /home/opadmin/.netrc
# True

# %%
opentable_artifact = wandb.Artifact("opentable_trajectories_gptv.v0", type="dataset")
# opentable_table = wandb.Table(dataframe=traj_df_new)
opentable_table_eligible = wandb.Table(dataframe=eligible_traj_df)
#
# opentable_artifact.add(opentable_table, "opentable")
opentable_artifact.add(opentable_table_eligible, "opentable-eligibleonly")
# opentable_artifact.add_file(str(dataset_path/'csv/data+gptv.csv'))
opentable_artifact.add_file(str(dataset_path/'csv/data+gptv-eligible.csv'))

# %%
# Start a W&B run to log data
run = wandb.init(project="opentable-vision", reinit=True)
# Log the table to visualize with a run...
run.log({"opentable_gptv": opentable_table_eligible})

# and Log as an Artifact to increase the available row limit!
run.log_artifact(opentable_artifact)
